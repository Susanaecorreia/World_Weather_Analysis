# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head(40)
# Out:
#     City_ID             City Country  Max Temp Current Description      Lat  \
# 0         0            Vaini      TO     84.20    scattered clouds -21.2000
# 1         6           Ixtapa      MX     75.20       broken clouds  20.7000
# 2         7         Araguacu      BR     75.97     overcast clouds -12.9306
# 3        15            Kapaa      US     77.00          light rain  22.0752
# 4        16           Atuona      PF     80.96     overcast clouds  -9.8000
# 5        18       Kabankalan      PH     82.08     overcast clouds   9.9889
# 6        22           Avarua      CK     82.40       broken clouds -21.2078
# 7        24   Saint-Philippe      RE     75.20          few clouds -21.3585
# 8        30       Georgetown      MY     80.01          light rain   5.4112
# 9        35           Faanui      PF     82.76    scattered clouds -16.4833
# 10       37            Adrar      MR     79.38     overcast clouds  20.5022
# 11       38         Salvador      SV     84.20           clear sky  13.8333
# 12       39              Eyl      SO     75.58    scattered clouds   7.9803
# 13       44        Carnarvon      AU     78.80           clear sky -24.8667
# 14       48   Kulhudhuffushi      MV     83.55     overcast clouds   6.6221
# 15       54     Port Hedland      AU     84.20          few clouds -20.3167
# 16       58        Sinnamary      GF     77.83     overcast clouds   5.3833
# 17       62          Ubatuba      BR     77.11       moderate rain -23.4339
# 18       65    Cockburn Town      TC     78.80    scattered clouds  21.4612
# 19       66        Bangassou      CF     75.67    scattered clouds   4.7413
# 20       68             Sola      VU     84.20     overcast clouds -13.8833
# 21       70              Sur      OM     82.74       broken clouds  22.5667
# 22       71        Mount Isa      AU     78.80           clear sky -20.7333
# 23       73            Bouna      CI     86.25     overcast clouds   9.2667
# 24       74     Puerto Ayora      EC     79.00    scattered clouds  -0.7393
# 25       77     Saint George      US     75.99           clear sky  37.1041
# 26       82             Atar      MR     76.03       broken clouds  20.5169
# 27       83        Alyangula      AU     85.53       broken clouds -13.8483
# 28       84          Mombasa      KE     77.41       broken clouds  -4.0547
# 29       85          Rikitea      PF     79.30           clear sky -23.1203
# 30       86           Ambulu      ID     77.63     overcast clouds  -8.3450
# 31       91           Touros      BR     80.60          few clouds  -5.1989
# 32       96             Mubi      NG     75.04           clear sky  10.2676
# 33       98  Bambous Virieux      MU     75.99          few clouds -20.3428
# 34       99           Dingle      PH     81.30     overcast clouds  10.9995
# 35      101       Mahibadhoo      MV     81.25     overcast clouds   3.7833
# 36      103        Kavaratti      IN     82.98     overcast clouds  10.5669
# 37      107   Cabo San Lucas      MX     77.00    scattered clouds  22.8909
# 38      109          Kahului      US     77.00    scattered clouds  20.8947
# 39      114       Vila Velha      BR     75.99           clear sky -20.3297
#
#          Lng                              Hotel Name
# 0  -175.2000                     Keleti Beach Resort
# 1  -105.2000                 Hotel Plaza Providencia
# 2   -49.8264                         Hotel Tocantins
# 3  -159.3190  Sheraton Kauai Resort at Coconut Beach
# 4  -139.0333                             Villa Enata
# 5   122.8122                  Southwoods Beach Lodge
# 6  -159.7750                            Paradise Inn
# 7    55.7679            Chambres d'hôte "La Trinité"
# 8   100.3354                          Cititel Penang
# 9  -151.7500      Bora-Bora Pearl Beach Resort & Spa
# 10  -10.0711                                     NaN
# 11  -88.9167                           Chico's Ranch
# 12   49.8164                             Amiin Hotel
# 13  113.6333                   Hospitality Carnarvon
# 14   73.0700                     Haajy Guest House 1
# 15  118.5667                     The Esplanade Hotel
# 16  -52.9500          ALETHEIA Appartement Sinnamary
# 17  -45.0711                          Hotel Coquille
# 18  -71.1419                      Osprey Beach Hotel
# 19   22.8184                                     NaN
# 20  167.5500                      Leumerus Bungalows
# 21   59.5289                         Sur Plaza Hotel
# 22  139.5000               ibis Styles Mt Isa Verona
# 23   -3.0000                           Hotel Reserve
# 24  -90.3518               Finch Bay Galapagos Hotel
# 25 -113.5841             Best Western Plus Abbey Inn
# 26  -13.0499                          Oumou Elghoura
# 27  136.4192                    Groote Eylandt Lodge
# 28   39.6636                     New Palm Tree Hotel
# 29 -134.9692                          Pension Maro'i
# 30  113.6058                     Hotel Ambulu Jember
# 31  -35.4608                         INN NEW HORIZON
# 32   13.2644                                   Hotel
# 33   57.7575                          Casa Tia Villa
# 34  122.6711                         SEGAYA PROPERTY
# 35   72.9667                             Omadhoo Inn
# 36   72.6420           Hotels in Lakshadweep Islands
# 37 -109.9124                  Hotel Tesoro Los Cabos
# 38 -156.4700                      Maui Seaside Hotel
# 39  -40.2925               Quality Suites Vila Velha

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             #max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"] == "Vila Velha")]
vacation_end = vacation_df.loc[(vacation_df["City"] == "Vila Velha")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"] == "Araguacu")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Ubatuba")] 
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Touros")] 
vacation_stop3
# Out:
#     City_ID    City Country  Max Temp Current Description     Lat      Lng  \
# 31       91  Touros      BR      80.6          few clouds -5.1989 -35.4608
#
#          Hotel Name
# 31  INN NEW HORIZON

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0],vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0],vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy(),vacation_stop1["Lng"].to_numpy()
stop2 = vacation_stop2["Lat"].to_numpy(),vacation_stop2["Lng"].to_numpy()
stop3 = vacation_stop3["Lat"].to_numpy(),vacation_stop3["Lng"].to_numpy()
start_tup = tuple(start)
end_tup = tuple(end)

#start_tup[0]
#end_tup[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
start = (-20.3297, -40.2925)
end = (-20.3297, -40.2925)
waypoints = [(-12.9306, -49.8264), (-23.4339, -45.0711), (-5.1989, -35.4608) ]
directions = gmaps.directions_layer(start, end, waypoints=waypoints, travel_mode='DRIVING')
fig.add_layer(directions)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0      114  Vila Velha      BR     75.99           clear sky -20.3297
# 1        7    Araguacu      BR     75.97     overcast clouds -12.9306
# 2       62     Ubatuba      BR     77.11       moderate rain -23.4339
# 3       91      Touros      BR     80.60          few clouds  -5.1989
# 4      114  Vila Velha      BR     75.99           clear sky -20.3297
#
#        Lng                 Hotel Name
# 0 -40.2925  Quality Suites Vila Velha
# 1 -49.8264            Hotel Tocantins
# 2 -45.0711             Hotel Coquille
# 3 -35.4608            INN NEW HORIZON
# 4 -40.2925  Quality Suites Vila Velha

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>

</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(-10, -50), zoom_level=7)
marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
